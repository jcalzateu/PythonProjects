# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
VR=[0,.2,.4,.6,.8,1.0,1.2,1.4,1.5,1.6,1.65,1.70,1.75,1.80,1.85,1.90,1.95,2.0,2.05,2.06]
IR=[0,0,0,.001,.001,.001,.001,.002,.007,.035,.081,.192,.433,.887,1.723,2.73,4.6,6.56,9.9,10.92]
VV=[0,.2,.4,.6,.8,1.0,1.2,1.4,1.5,1.6,1.7,1.8,1.9,2.0,2.05,2.1,2.15,2.2,2.25,2.3,2.35,2.4,2.45,2.5,2.55,2.6,2.65,2.7,2.75,2.8,2.84]
IV=[0,0,0,.001,.001,.001,.001,.001,.002,.002,.002,.002,.002,.003,.007,.017,.052,.152,.275,.499,.744,1.078,1.432,1.88,2.42,2.98,3.75,4.51,5.58,6.76,7.95]
VA=[0,.2,.4,.6,.8,1.0,1.2,1.4,1.5,1.6,1.7,1.8,1.9,2.0,2.1,2.2,2.3,2.35,2.4,2.45,2.5,2.55,2.6,2.65,2.7,2.75,2.8]
IA=[0,0,0,.001,.001,.001,.001,.001,.002,.002,.002,.002,.002,.002,.002,.002,.003,.004,.008,.031,.127,.477,1.203,2.55,3.96,5.72,8.18]

# %%
# Grafica del led rojo
plt.plot(VR,IR,color='red')
# Grafica del led verde
plt.plot(VV,IV,color='green')
# Grafica del led azul
plt.plot(VA,IA,color='blue')

plt.xlabel('Voltaje',{'color':'blue',
           'fontsize':12, 'fontstyle':'italic',
           'rotation':359,'verticalalignment':'center',
           'family':'cursive'})
plt.ylabel('Corriente',{'color':'blue',
           'fontsize':12, 'fontstyle':'italic',
           'rotation':300,'verticalalignment':'center',
           'family':'cursive'})
Atributos={'color':'red',
           'fontsize':20, 'fontstyle':'italic',
           'rotation':0,'verticalalignment':'center',
           'family':'cursive'}
plt.title('Corriente vs Voltaje',{'color':'red',
           'fontsize':20, 'fontstyle':'italic',
           'rotation':359,'verticalalignment':'center',
           'family':'cursive'})
plt.legend(['Led Rojo','Led Verde','Led Azul'],loc='best', shadow=True, fontsize='x-large').get_frame().set_facecolor('w')
plt.grid()

# %%
conta=0
y=np.zeros(len(VR))
for i in VR:
  y[conta]=2.98*(VR[conta])-2.1805
  conta=conta+1
plt.plot(VR,IR,color='red')
plt.plot(VR,y,color='blue')
# plt.scatter([0,2.1805/2.98],[0,0],100,color='blue')
# plt.plot(0,2.1805/2.98,color='green',linewidth=10,linestyle="--")
t=1.5
plt.xlabel('Voltaje',{'color':'black',
           'fontsize':20, 'fontstyle':'italic',
           'rotation':0,'verticalalignment':'center',
           'family':'cursive'})
plt.ylabel('Corriente',{'color':'black',
           'fontsize':20, 'fontstyle':'italic',
           'rotation':90,'verticalalignment':'center',
           'family':'monospace'})
plt.annotate(r'$(V.KNEE)$',
             xy=(2.1805/2.98,0), xycoords='data',
             xytext=(9,81), textcoords='offset points', fontsize=20,
             arrowprops=dict(arrowstyle="wedge", connectionstyle="arc3,rad=.2",color='green'))
plt.annotate(r'$y=2.98\cdot\:X-2.1805$',
             xy=(t,2.98*t-2.1805), xycoords='data',
             xytext=(+40,+40), textcoords='offset points', fontsize=20,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2",color='black'))
plt.legend(['Led Rojo','Linealización','V.KNEE'],loc='best', shadow=True, fontsize='x-large').get_frame().set_facecolor('w')

plt.grid()
